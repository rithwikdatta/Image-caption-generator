# %%
import os
import re
import gc
import numpy as np
import collections
from PIL import Image
from textwrap import wrap
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from tqdm import tqdm_notebook as tqdm

from keras.utils import to_categorical
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.image import load_img, img_to_array

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.layers import Input, Dropout, Dense, Embedding, LSTM, add
# Out:
# Using TensorFlow backend.

# %%
def clean_description(desc, stopwords):

  cleaned = desc.lower()
  cleaned = re.sub('[^a-z]',' ',cleaned)
  tokens = cleaned.split(' ')
  cleaned = ' '.join([w for w in tokens if w not in stopwords and len(w)>1])
  
  return cleaned

# %%
def get_vocabulary(dictionary):
  vocab = set()

  for desc_list in dictionary.values():
    for desc in desc_list:
      words = desc.split(' ')
      for word in words:
        vocab.add(word)

  return vocab

# %%
with open('C:\\Users\\Rithwik Datta\\ML\\majorproject\\Flickr8k.token.txt', 'r') as f:
  all_desc = f.read().split('\n')

# %%
all_desc[:5]

# %%
stopwords = ['is', 'an', 'a', 'the', 'was']

# %%
all_dict = dict()

for desc in all_desc:
  if len(desc) < 1:
    continue
  file_name, file_desc = desc.split('\t')[0].split('.')[0], desc.split('\t')[1]
  
  if file_name not in all_dict.keys():
    all_dict[file_name] = []

  cleaned_desc = clean_description(file_desc, stopwords)
  cleaned_desc = 'startseq ' + cleaned_desc + ' endseq'

  all_dict[file_name].append(cleaned_desc)

# %%
vocab = get_vocabulary(all_dict)

# %%
print('Total images:', len(all_dict))
print('Total vocabulary without stopwords:', len(vocab))

# %%
# !wget https://banner2.cleanpng.com//20181128//vpu//kisspng-cloud-computing-scalable-vector-graphics-joruri-po-5bfe80dc1e3ab9.9777518815434057881238.jpg > //dev//null

# %%
all_sent_list = [item.strip('startseq').strip('endseq').strip(' ') for sublist in list(all_dict.values()) for item in sublist]

# %%
all_sent_len = [len(sent) for sent in all_sent_list]

# %%
plt.hist([len(sentence.split()) for sentence in all_sent_list])
plt.xlabel('Number of words')
plt.ylabel('Number of sentenes')
plt.title('Count of number of words in sentences')
plt.show()

# %%
avg_sent_len = int(np.mean([len(sentence.split()) for sentence in all_sent_list]))
avg_sent_len

# %%
words = [w for a in all_sent_list for w in a.split(' ')]

# %%
counts = collections.Counter(words)
most_common = counts.most_common()
most_common[:15]

# %%
keys = [tupl[0] for tupl in most_common][:15]
values = [tupl[1] for tupl in most_common][:15]

# %%
plt.figure(figsize=(8, 8))
plt.bar(keys, values)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Frequency of most common words')
plt.show()

# %%
lengths = set()
for cap_list in all_dict.values():
  lengths.add(len(cap_list))

print('Number of captions for each image: ', lengths)

# %%
fig = plt.figure()
fig.suptitle('Sample images', fontsize=20)

zoom = 3
w, h = fig.get_size_inches()
fig.set_size_inches(w * zoom, h * zoom)
fig.tight_layout()

for i in range(1, 26):
  ax = fig.add_subplot(5, 5, i)
  ax.imshow(plt.imread('Images/'+list(all_dict.keys())[i-1]+'.jpg'))
  plt.axis('off')

plt.show()

# %%
fig = plt.figure()
fig.suptitle('Sample images with one of the captions', fontsize=20)

zoom = 2
w, h = fig.get_size_inches()
fig.set_size_inches(w * zoom, h * zoom)

for i in range(1, 5):
  ax = fig.add_subplot(2, 2, i)
  ax.imshow(plt.imread('Images/'+list(all_dict.keys())[i-1]+'.jpg'))
  title = ax.set_title('\n'.join(wrap(all_dict.get(list(all_dict.keys())[i-1])[0], 60)))
  fig.tight_layout(h_pad=2)
  title.set_y(1.05)
  plt.axis('off')
  fig.subplots_adjust(top=0.85, hspace=0.3)

plt.show()

# %%
xcep = Xception(include_top=False, pooling='avg')

# %%
predictions = dict()

for dirpath, dirname, files in os.walk('Images'):
  for filename in tqdm(files):
    img_path = os.path.join(dirpath, filename)
    if os.path.isfile(img_path):
      img = Image.open(img_path)
      img = img.resize((299,299))
      img = np.expand_dims(img, axis=0)
      img = img/127.5
      img = img - 1.0

      predictions[filename.split('.')[0]] = xcep.predict(img)
# Out:
# C:\Users\Rithwik\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8091.0), HTML(value='')))

# %%
print('Number of extracted features:', len(predictions.get(list(predictions.keys())[0])[0]))
# Out:
# Number of extracted features: 2048

# %%
predictions.get(list(predictions.keys())[0])
# Out:
# array([[0.47340968, 0.01730898, 0.07334232, ..., 0.08557959, 0.02102299,
#         0.23765522]], dtype=float32)

# %%
def create_list(dictionary):
  final_list = []

  for desc_list in dictionary.values():
    for desc in desc_list:
      final_list.append(desc)

  return final_list

# %%
def fit_tokenizer(dictionary):
  desc_list = create_list(dictionary)
  tokenizer = Tokenizer()
  tokenizer.fit_on_texts(desc_list)
  return tokenizer

# %%
def convert_to_input(tokens, pos, im_name, max_len, vocab_len, tokenizer, img_predictions):

  inp = tokens[:pos]
  out = tokens[pos]
  inp = pad_sequences(sequences=[inp], maxlen=max_len)[0]
  out = to_categorical(y=[out], num_classes=vocab_len, dtype='bool')[0]
  
  return img_predictions.get(im_name)[0], inp, out

# %%
def convert_all_to_input(dictionary, max_len, vocab_len, tokenizer, img_predictions):
  
  X_1 = list()
  X_2 = list()
  y = list()

  for im_name, descriptions in tqdm(dictionary.items()):
    if im_name in img_predictions.keys():
      for desc in descriptions:
          tokens = tokenizer.texts_to_sequences([desc])[0]
          for i in range(1, len(tokens)):
              _X_1, _X_2, _y = convert_to_input(tokens, i, im_name, max_len, vocab_len, tokenizer, img_predictions)
              X_1.append(_X_1)
              X_2.append(_X_2)
              y.append(_y)
  return np.array(X_1), np.array(X_2), np.array(y)

# %%
tokenizer = fit_tokenizer(all_dict)

# %%
vocab_len = len(tokenizer.index_word) + 1
vocab_len
# Out:
# 8423

# %%
max_len = len(max(create_list(all_dict)))
max_len
# Out:
# 93

# %%
cnn_len = predictions[list(predictions.keys())[0]].shape[1]
cnn_len
# Out:
# 2048

# %%
X_1, X_2, y = convert_all_to_input(all_dict, max_len, vocab_len, tokenizer, predictions)
# Out:
# C:\Users\Rithwik\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8092.0), HTML(value='')))

# %%
def shuffle_arrays(arrays, set_seed=-1):
    """Shuffles arrays in-place, in the same order, along axis=0

    Parameters:
    -----------
    arrays : List of NumPy arrays.
    set_seed : Seed value if int >= 0, else seed is random.
    """
    assert all(len(arr) == len(arrays[0]) for arr in arrays)
    seed = np.random.randint(0, 2**(32 - 1) - 1) if set_seed < 0 else set_seed

    for arr in arrays:
        rstate = np.random.RandomState(seed)
        rstate.shuffle(arr)

# %%
shuffle_arrays([X_1, X_2, y])

# %%
def create_model(cnn_len, max_len, vocab_len):
  cnn_in = Input(shape=(cnn_len,))
  cnn_x = Dropout(0.5)(cnn_in)
  cnn_out = Dense(units=256, activation='relu')(cnn_x)

  lstm_in = Input(shape=(max_len,))
  lstm_x = Embedding(vocab_len, 256, mask_zero=True)(lstm_in)
  lstm_x = Dropout(0.5)(lstm_x)
  lstm_out = LSTM(256)(lstm_x)

  combined = add([cnn_out, lstm_out])
  combined_x = Dense(units=256, activation='relu')(combined)
  output = Dense(units=vocab_len, activation='softmax')(combined_x)

  model = Model(inputs=[cnn_in, lstm_in], outputs=output)

  return model

# %%
model = create_model(cnn_len, max_len, vocab_len)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), 
            loss=tf.keras.losses.categorical_crossentropy, 
            metrics=[tf.keras.metrics.categorical_accuracy])

# %%
batch_size=4096

for i in tqdm(range(0, len(X_1), batch_size)):
  model.fit(x=[X_1[i:i+batch_size], X_2[i:i+batch_size]], y=y[i:i+batch_size], epochs=2, batch_size=256)
# Out:
# C:\Users\Rithwik\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=94.0), HTML(value='')))
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 107s 26ms/sample - loss: 7.5301 - categorical_accuracy: 0.0793
# Epoch 2/2
# 4096/4096 [==============================] - 31s 8ms/sample - loss: 5.8737 - categorical_accuracy: 0.0962
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 31s 8ms/sample - loss: 6.2589 - categorical_accuracy: 0.1086
# Epoch 2/2
# 4096/4096 [==============================] - 31s 8ms/sample - loss: 5.7424 - categorical_accuracy: 0.1255
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 6.0224 - categorical_accuracy: 0.1245
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 5.5365 - categorical_accuracy: 0.1370
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 5.7359 - categorical_accuracy: 0.1450
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 5.2950 - categorical_accuracy: 0.1504
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 5.5993 - categorical_accuracy: 0.1453
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 5.1762 - categorical_accuracy: 0.1533
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 5.3631 - categorical_accuracy: 0.1699
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 4.9714 - categorical_accuracy: 0.1763
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 37s 9ms/sample - loss: 5.1944 - categorical_accuracy: 0.1672
# Epoch 2/2
# 4096/4096 [==============================] - 31s 8ms/sample - loss: 4.7822 - categorical_accuracy: 0.1775
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 40s 10ms/sample - loss: 5.1096 - categorical_accuracy: 0.1685
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 4.7075 - categorical_accuracy: 0.1826
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 36s 9ms/sample - loss: 4.9927 - categorical_accuracy: 0.1890
# Epoch 2/2
# 4096/4096 [==============================] - 33s 8ms/sample - loss: 4.6238 - categorical_accuracy: 0.1960
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 59s 14ms/sample - loss: 4.9060 - categorical_accuracy: 0.1936
# Epoch 2/2
# 4096/4096 [==============================] - 50s 12ms/sample - loss: 4.5640 - categorical_accuracy: 0.2095
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 36s 9ms/sample - loss: 4.8151 - categorical_accuracy: 0.1943
# Epoch 2/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 4.4944 - categorical_accuracy: 0.2024
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 4.8316 - categorical_accuracy: 0.2083
# Epoch 2/2
# 4096/4096 [==============================] - 31s 8ms/sample - loss: 4.4928 - categorical_accuracy: 0.2170
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 33s 8ms/sample - loss: 4.7088 - categorical_accuracy: 0.2102
# Epoch 2/2
# 4096/4096 [==============================] - 31s 7ms/sample - loss: 4.3896 - categorical_accuracy: 0.2253
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 4.6942 - categorical_accuracy: 0.2163
# Epoch 2/2
# 4096/4096 [==============================] - 31s 8ms/sample - loss: 4.3525 - categorical_accuracy: 0.2332
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 51s 13ms/sample - loss: 4.6248 - categorical_accuracy: 0.2109
# Epoch 2/2
# 4096/4096 [==============================] - 49s 12ms/sample - loss: 4.2935 - categorical_accuracy: 0.2322
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 50s 12ms/sample - loss: 4.6007 - categorical_accuracy: 0.2207
# Epoch 2/2
# 4096/4096 [==============================] - 48s 12ms/sample - loss: 4.2841 - categorical_accuracy: 0.2371
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 4.5583 - categorical_accuracy: 0.2312
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 4.2272 - categorical_accuracy: 0.2415
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 4.5410 - categorical_accuracy: 0.2410
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 4.2157 - categorical_accuracy: 0.2532
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 33s 8ms/sample - loss: 4.4546 - categorical_accuracy: 0.2407
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 4.1227 - categorical_accuracy: 0.2537
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 4.5551 - categorical_accuracy: 0.2363
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 4.2244 - categorical_accuracy: 0.2507
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 4.3721 - categorical_accuracy: 0.2415
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 4.0523 - categorical_accuracy: 0.2622
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 4.3637 - categorical_accuracy: 0.2473
# Epoch 2/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 4.0387 - categorical_accuracy: 0.2603
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 35s 9ms/sample - loss: 4.4351 - categorical_accuracy: 0.2424
# Epoch 2/2
# 4096/4096 [==============================] - 33s 8ms/sample - loss: 4.1145 - categorical_accuracy: 0.2500
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 37s 9ms/sample - loss: 4.4059 - categorical_accuracy: 0.2498
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 4.0760 - categorical_accuracy: 0.2581
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 38s 9ms/sample - loss: 4.2330 - categorical_accuracy: 0.2690
# Epoch 2/2
# 4096/4096 [==============================] - 33s 8ms/sample - loss: 3.9172 - categorical_accuracy: 0.2798
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 40s 10ms/sample - loss: 4.2687 - categorical_accuracy: 0.2517
# Epoch 2/2
# 4096/4096 [==============================] - 36s 9ms/sample - loss: 3.9195 - categorical_accuracy: 0.2671
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 35s 9ms/sample - loss: 4.2972 - categorical_accuracy: 0.2573
# Epoch 2/2
# 4096/4096 [==============================] - 37s 9ms/sample - loss: 3.9671 - categorical_accuracy: 0.2800
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 37s 9ms/sample - loss: 4.2352 - categorical_accuracy: 0.2603
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.9029 - categorical_accuracy: 0.2771
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 4.3013 - categorical_accuracy: 0.2505
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.9669 - categorical_accuracy: 0.2678
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 4.2446 - categorical_accuracy: 0.2466
# Epoch 2/2
# 4096/4096 [==============================] - 33s 8ms/sample - loss: 3.9195 - categorical_accuracy: 0.2639
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 54s 13ms/sample - loss: 4.1374 - categorical_accuracy: 0.2632
# Epoch 2/2
# 4096/4096 [==============================] - 38s 9ms/sample - loss: 3.8212 - categorical_accuracy: 0.2874
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 56s 14ms/sample - loss: 4.2154 - categorical_accuracy: 0.2646
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.8774 - categorical_accuracy: 0.2834
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 41s 10ms/sample - loss: 4.1925 - categorical_accuracy: 0.2607
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.8568 - categorical_accuracy: 0.2778
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 38s 9ms/sample - loss: 4.1907 - categorical_accuracy: 0.2646
# Epoch 2/2
# 4096/4096 [==============================] - 33s 8ms/sample - loss: 3.8589 - categorical_accuracy: 0.2822
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 38s 9ms/sample - loss: 4.1070 - categorical_accuracy: 0.2693
# Epoch 2/2
# 4096/4096 [==============================] - 31s 8ms/sample - loss: 3.7763 - categorical_accuracy: 0.2927
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 35s 9ms/sample - loss: 4.2050 - categorical_accuracy: 0.2688
# Epoch 2/2
# 4096/4096 [==============================] - 31s 8ms/sample - loss: 3.8579 - categorical_accuracy: 0.2852
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 4.0253 - categorical_accuracy: 0.2830
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 3.6893 - categorical_accuracy: 0.3030
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 52s 13ms/sample - loss: 4.1064 - categorical_accuracy: 0.2678
# Epoch 2/2
# 4096/4096 [==============================] - 38s 9ms/sample - loss: 3.7639 - categorical_accuracy: 0.2881
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 50s 12ms/sample - loss: 4.1609 - categorical_accuracy: 0.2585
# Epoch 2/2
# 4096/4096 [==============================] - 50s 12ms/sample - loss: 3.8053 - categorical_accuracy: 0.2947
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 4.1209 - categorical_accuracy: 0.2742
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 3.7834 - categorical_accuracy: 0.2961
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 4.1936 - categorical_accuracy: 0.2678
# Epoch 2/2
# 4096/4096 [==============================] - 35s 9ms/sample - loss: 3.8342 - categorical_accuracy: 0.2817
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 35s 9ms/sample - loss: 4.0380 - categorical_accuracy: 0.2773
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.6920 - categorical_accuracy: 0.2971
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 39s 10ms/sample - loss: 4.0400 - categorical_accuracy: 0.2781
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.7008 - categorical_accuracy: 0.3000
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 58s 14ms/sample - loss: 3.9861 - categorical_accuracy: 0.2781
# Epoch 2/2
# 4096/4096 [==============================] - 53s 13ms/sample - loss: 3.6420 - categorical_accuracy: 0.2961
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 4.0149 - categorical_accuracy: 0.2710
# Epoch 2/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 3.6695 - categorical_accuracy: 0.2859
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 36s 9ms/sample - loss: 4.0554 - categorical_accuracy: 0.2627
# Epoch 2/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 3.7102 - categorical_accuracy: 0.2961
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 40s 10ms/sample - loss: 3.9377 - categorical_accuracy: 0.2886
# Epoch 2/2
# 4096/4096 [==============================] - 35s 9ms/sample - loss: 3.6079 - categorical_accuracy: 0.3118
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 42s 10ms/sample - loss: 3.9165 - categorical_accuracy: 0.2808
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.5690 - categorical_accuracy: 0.3083
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 39s 10ms/sample - loss: 3.9449 - categorical_accuracy: 0.2893
# Epoch 2/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 3.6056 - categorical_accuracy: 0.3140
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 54s 13ms/sample - loss: 4.0156 - categorical_accuracy: 0.2815
# Epoch 2/2
# 4096/4096 [==============================] - 49s 12ms/sample - loss: 3.6665 - categorical_accuracy: 0.3052
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 36s 9ms/sample - loss: 3.9736 - categorical_accuracy: 0.2791
# Epoch 2/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 3.6341 - categorical_accuracy: 0.3013
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 33s 8ms/sample - loss: 4.1123 - categorical_accuracy: 0.2791
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 3.7641 - categorical_accuracy: 0.3008
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 43s 10ms/sample - loss: 3.9947 - categorical_accuracy: 0.2739
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 3.6414 - categorical_accuracy: 0.3059
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 41s 10ms/sample - loss: 3.9367 - categorical_accuracy: 0.2861
# Epoch 2/2
# 4096/4096 [==============================] - 29s 7ms/sample - loss: 3.6055 - categorical_accuracy: 0.3088
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 43s 10ms/sample - loss: 3.8961 - categorical_accuracy: 0.2944
# Epoch 2/2
# 4096/4096 [==============================] - 31s 8ms/sample - loss: 3.5582 - categorical_accuracy: 0.3159
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 42s 10ms/sample - loss: 4.0169 - categorical_accuracy: 0.2683
# Epoch 2/2
# 4096/4096 [==============================] - 30s 7ms/sample - loss: 3.6665 - categorical_accuracy: 0.2974
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 39s 10ms/sample - loss: 3.9526 - categorical_accuracy: 0.2830
# Epoch 2/2
# 4096/4096 [==============================] - 31s 7ms/sample - loss: 3.6148 - categorical_accuracy: 0.3027
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 41s 10ms/sample - loss: 4.0095 - categorical_accuracy: 0.2708
# Epoch 2/2
# 4096/4096 [==============================] - 32s 8ms/sample - loss: 3.6544 - categorical_accuracy: 0.2964
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 49s 12ms/sample - loss: 3.8822 - categorical_accuracy: 0.2881
# Epoch 2/2
# 4096/4096 [==============================] - 38s 9ms/sample - loss: 3.5455 - categorical_accuracy: 0.3083
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 48s 12ms/sample - loss: 3.8427 - categorical_accuracy: 0.2756
# Epoch 2/2
# 4096/4096 [==============================] - 36s 9ms/sample - loss: 3.5067 - categorical_accuracy: 0.3071
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 60s 15ms/sample - loss: 3.8984 - categorical_accuracy: 0.2861
# Epoch 2/2
# 4096/4096 [==============================] - 46s 11ms/sample - loss: 3.5609 - categorical_accuracy: 0.3147
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 52s 13ms/sample - loss: 3.8831 - categorical_accuracy: 0.2959
# Epoch 2/2
# 4096/4096 [==============================] - 47s 11ms/sample - loss: 3.5453 - categorical_accuracy: 0.3184
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 49s 12ms/sample - loss: 3.9474 - categorical_accuracy: 0.2849
# Epoch 2/2
# 4096/4096 [==============================] - 35s 9ms/sample - loss: 3.5957 - categorical_accuracy: 0.3096
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 46s 11ms/sample - loss: 3.8553 - categorical_accuracy: 0.2961
# Epoch 2/2
# 4096/4096 [==============================] - 33s 8ms/sample - loss: 3.5112 - categorical_accuracy: 0.3206
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 39s 10ms/sample - loss: 3.9159 - categorical_accuracy: 0.2864
# Epoch 2/2
# 4096/4096 [==============================] - 33s 8ms/sample - loss: 3.5693 - categorical_accuracy: 0.3071
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 44s 11ms/sample - loss: 3.8703 - categorical_accuracy: 0.2844
# Epoch 2/2
# 4096/4096 [==============================] - 37s 9ms/sample - loss: 3.5347 - categorical_accuracy: 0.3115
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 39s 10ms/sample - loss: 3.8589 - categorical_accuracy: 0.2839
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.5221 - categorical_accuracy: 0.3135
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 41s 10ms/sample - loss: 3.7679 - categorical_accuracy: 0.3015
# Epoch 2/2
# 4096/4096 [==============================] - 35s 9ms/sample - loss: 3.4201 - categorical_accuracy: 0.3264
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 39s 10ms/sample - loss: 3.8645 - categorical_accuracy: 0.2925
# Epoch 2/2
# 4096/4096 [==============================] - 37s 9ms/sample - loss: 3.5437 - categorical_accuracy: 0.3186
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 41s 10ms/sample - loss: 3.7781 - categorical_accuracy: 0.2935
# Epoch 2/2
# 4096/4096 [==============================] - 36s 9ms/sample - loss: 3.4409 - categorical_accuracy: 0.3157
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 64s 16ms/sample - loss: 3.8895 - categorical_accuracy: 0.2883
# Epoch 2/2
# 4096/4096 [==============================] - 61s 15ms/sample - loss: 3.5405 - categorical_accuracy: 0.3081
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 57s 14ms/sample - loss: 3.8493 - categorical_accuracy: 0.2925
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.4930 - categorical_accuracy: 0.3242
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 51s 13ms/sample - loss: 3.8659 - categorical_accuracy: 0.2830
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.5138 - categorical_accuracy: 0.3096
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 41s 10ms/sample - loss: 3.8390 - categorical_accuracy: 0.2935
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.5089 - categorical_accuracy: 0.3101
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 38s 9ms/sample - loss: 3.7998 - categorical_accuracy: 0.2954
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.4623 - categorical_accuracy: 0.3247
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 40s 10ms/sample - loss: 3.7621 - categorical_accuracy: 0.3052
# Epoch 2/2
# 4096/4096 [==============================] - 35s 8ms/sample - loss: 3.4277 - categorical_accuracy: 0.3301
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 62s 15ms/sample - loss: 3.7149 - categorical_accuracy: 0.2971
# Epoch 2/2
# 4096/4096 [==============================] - 45s 11ms/sample - loss: 3.3794 - categorical_accuracy: 0.3311
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 37s 9ms/sample - loss: 3.8166 - categorical_accuracy: 0.2954
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.4784 - categorical_accuracy: 0.3191
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 42s 10ms/sample - loss: 3.7440 - categorical_accuracy: 0.3064
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.3984 - categorical_accuracy: 0.3350
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 39s 10ms/sample - loss: 3.7512 - categorical_accuracy: 0.3025
# Epoch 2/2
# 4096/4096 [==============================] - 36s 9ms/sample - loss: 3.4333 - categorical_accuracy: 0.3274
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 66s 16ms/sample - loss: 3.7488 - categorical_accuracy: 0.2888
# Epoch 2/2
# 4096/4096 [==============================] - 60s 15ms/sample - loss: 3.4057 - categorical_accuracy: 0.3208
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 46s 11ms/sample - loss: 3.8024 - categorical_accuracy: 0.2996
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.4497 - categorical_accuracy: 0.3237
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 41s 10ms/sample - loss: 3.7663 - categorical_accuracy: 0.2964
# Epoch 2/2
# 4096/4096 [==============================] - 36s 9ms/sample - loss: 3.4220 - categorical_accuracy: 0.3223
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 40s 10ms/sample - loss: 3.8381 - categorical_accuracy: 0.2856
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.4779 - categorical_accuracy: 0.3152
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 38s 9ms/sample - loss: 3.7098 - categorical_accuracy: 0.2986
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.3765 - categorical_accuracy: 0.3279
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 38s 9ms/sample - loss: 3.8170 - categorical_accuracy: 0.2961
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.4709 - categorical_accuracy: 0.3257
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 42s 10ms/sample - loss: 3.8176 - categorical_accuracy: 0.2952
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.4670 - categorical_accuracy: 0.3232
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 38s 9ms/sample - loss: 3.7035 - categorical_accuracy: 0.3101
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.3675 - categorical_accuracy: 0.3311
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 44s 11ms/sample - loss: 3.7992 - categorical_accuracy: 0.2930
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.4607 - categorical_accuracy: 0.3186
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 37s 9ms/sample - loss: 3.7131 - categorical_accuracy: 0.3066
# Epoch 2/2
# 4096/4096 [==============================] - 34s 8ms/sample - loss: 3.3731 - categorical_accuracy: 0.3289
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 45s 11ms/sample - loss: 3.7294 - categorical_accuracy: 0.3027
# Epoch 2/2
# 4096/4096 [==============================] - 36s 9ms/sample - loss: 3.3980 - categorical_accuracy: 0.3315
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 42s 10ms/sample - loss: 3.7319 - categorical_accuracy: 0.3030
# Epoch 2/2
# 4096/4096 [==============================] - 37s 9ms/sample - loss: 3.3996 - categorical_accuracy: 0.3289
# Train on 4096 samples
# Epoch 1/2
# 4096/4096 [==============================] - 47s 11ms/sample - loss: 3.6705 - categorical_accuracy: 0.3079
# Epoch 2/2
# 4096/4096 [==============================] - 35s 9ms/sample - loss: 3.3664 - categorical_accuracy: 0.3318
# Train on 3122 samples
# Epoch 1/2
# 3122/3122 [==============================] - 126s 40ms/sample - loss: 3.7050 - categorical_accuracy: 0.3037
# Epoch 2/2
# 3122/3122 [==============================] - 30s 10ms/sample - loss: 3.3940 - categorical_accuracy: 0.3280

# %%
def word_for_id(integer, tokenizer):

	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	
	return None

# %%
def generate_desc(model, tokenizer, photo, max_len):
	
	start_text = 'startseq'

	for i in range(max_len):

		tokens = tokenizer.texts_to_sequences([start_text])[0]

		tokens = pad_sequences([tokens], maxlen=max_len)

		pred = model.predict([photo, tokens], verbose=0)

		pred = np.argmax(pred)

		word = word_for_id(pred, tokenizer)

		if word is None:
			break

		start_text += ' ' + word

		if word == 'endseq':
			break

	return start_text

# %%
img_path = 'E:\\ML subject\\basketball.png'
img = Image.open(img_path)
img2 = img.copy()
img = img.resize((299,299))
img = np.expand_dims(img, axis=0)
img = img/127.5
img = img - 1.0
pred = xcep.predict(img)

plt.figure(figsize=(10, 10))
plt.imshow(img2)
plt.axis('off')
plt.show()

caption = generate_desc(model, tokenizer, pred, 93)
caption = caption.strip('startseq').strip('endseq')
print(caption)
# Out:
# 8423
#  basketball player in white uniform and white uniform jumps

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 93)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 2048)]       0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 93, 256)      2156288     input_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           input_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 93, 256)      0           embedding[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          524544      dropout[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 256)          525312      dropout_1[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 256)          0           dense[0][0]
#                                                                  lstm[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          65792       add_12[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8423)         2164711     dense_1[0][0]
# ==================================================================================================
# Total params: 5,436,647
# Trainable params: 5,436,647
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
img_path = 'E:\\ML subject\\test1.jpeg'
img = Image.open(img_path)
img2 = img.copy()
img = img.resize((299,299))
img = np.expand_dims(img, axis=0)
img = img/127.5
img = img - 1.0
pred = xcep.predict(img)

plt.figure(figsize=(10, 10))
plt.imshow(img2)
plt.axis('off')
plt.show()

caption = generate_desc(model, tokenizer, pred, 93)
caption = caption.strip('startseq').strip('endseq')
print(caption)
# Out:
#  two young girls are posing for picture

# %%
from gtts import gTTS 
import os

# %%
text=caption
language='en'

# %%
speech = gTTS(text = text, lang = language, slow = False)

# %%
speech.save("text.mp3")

# %%
from IPython.display import HTML

# %%
json_file = model.to_json()
with open(json_file_path, "w") as file:
   file.write(json_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-cf15203c68f9> in <module>
#       1 json_file = model.to_json()
# ----> 2 with open(json_file_path, "w") as file:
#       3    file.write(json_file)
#       4 # serialize weights to HDF5
#       5 model.save_weights(h5_file)
#
# NameError: name 'json_file_path' is not defined

# %%
from tensorflow.keras.models import load_model
loaded_model = load_model("network.h5",compile=False)

# %%
X_1, X_2, y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1f55c89bef4c> in <module>
# ----> 1 X_1, X_2, y
#
# NameError: name 'X_1' is not defined

# %%
# %store -r X_1
